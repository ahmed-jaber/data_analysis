# %%
import pandas as pd

df=pd.read_csv('failures.csv')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Age       6 non-null      int64
#  1   Failures  6 non-null      int64
#  2   DaysOff   6 non-null      int64
# dtypes: int64(3)
# memory usage: 272.0 bytes

# %%
import matplotlib.pyplot as plt

plt.plot(df['Failures'])

# %%
plt.plot(df['Failures'],marker='o')

# %%
plt.plot(df['Failures'],marker='o',ls=':')

# %%
plt.plot(df['Failures'],color='red',linewidth='10')

# %%
y1=df['Failures']
y2=df['Age']
plt.plot(y1,marker='o')
plt.plot(y2,marker='o')

# %%
df=pd.read_csv('failures2.csv')
x=df['Machine']
y=df['Failures']

xLabel='Machine'
yLabel='Failures'

plt.xlabel(xLabel)
plt.ylabel(yLabel)

plt.bar(x,y)
# Out:
# <BarContainer object of 5 artists>

# %%
plt.pie(y,labels=x)
# Out:
# ([<matplotlib.patches.Wedge at 0x17fc86da740>,
#   <matplotlib.patches.Wedge at 0x17fc86dab60>,
#   <matplotlib.patches.Wedge at 0x17fc86dafe0>,
#   <matplotlib.patches.Wedge at 0x17fc86db340>,
#   <matplotlib.patches.Wedge at 0x17fc86db7c0>],
#  [Text(1.0696069100332037, 0.2567899102558786, 'A'),
#   Text(0.6465637441936395, 0.8899187180267095, 'B'),
#   Text(-0.49938961394847997, 0.9801071438778458, 'C'),
#   Text(-1.0162674463500614, -0.42095187075142576, 'D'),
#   Text(0.646563910834035, -0.8899185969553609, 'E')])

# %%
df=pd.read_csv('failures.csv')

y1=df['Age']
y2=df['Failures']

plt.subplot(1,2,1)
plt.plot(y1,y2,marker='o')

plt.subplot(1,2,2)
plt.plot(y2,y1,marker='o')
